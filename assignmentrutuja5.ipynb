# %% [markdown]
# name||RUTUJA BADKAS

# %% [markdown]
# CO|| ASSIGNMENT 5

# %% [markdown]
# Q.1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import numpy as np
years = ['2003', '2004', '2005', '2006', '2009']
sachin = [500, 700, 1100, 1500, 1800, ]
sehwag = [ 1800, 1500, 1100, 800, 0]
kohli  = [0, 1500, 1800, 1900, 2100]

x = np.arange(len(years))  
width = 0.25

plt.bar(x - width, sachin_runs, width=width, label="Sachin")
plt.bar(x, sehwag_runs, width=width, label="Sehwag")
plt.bar(x + width, kohli_runs, width=width, label="Kohli")

plt.xlabel("Year")
plt.ylabel("Runs")
plt.title("Runs selected years")
plt.xticks(x, years) 
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

sachin_5yr = [400, 700, 1100, 500, 800, ]
sehwag_5yr = [ 1200, 1100, 100, 400, 100]
kohli_5yr = [0, 1500, 600, 1230, 1900]

total_runs = [sum(sachin_5yr),
              sum(sehwag_5yr),
              sum(kohli_5yr)]

players = ['Sachin', 'Sehwag', 'Kohli']

plt.barh(players,total_runs, ) 
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.figure(figsize=(8,5))
plt.xlabel("total_runs")
#plt.ylabel("players")
plt.title("5years of career")
#plt.xticks(x, years) 
plt.legend()
plt.tight_layout()
plt.show ()
# Out:
# C:\Users\shiraswal\AppData\Local\Temp\ipykernel_27356\2102759460.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use("ggplot")

# %%
# Data
labels = ['Android', 'iOS', 'Others']
share = [41, 23, 36]

# %%
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title("Market Share Of Mobile OS")
colors =['#66b3ff','#99ff99','#ffcc99']
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
labels = ['Android', 'iOS', 'Others']
share = [41, 23, 36]

# %%
plt.barh(labels,sizes)
width =0.8
plt.ylabel("label")
plt.xlabel("share%")
plt.title("Market Share Of Mobile OS")
plt.show()
